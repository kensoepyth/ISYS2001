# %% [markdown]
# <a href="https://colab.research.google.com/github/kensoepyth/ISYS2001/blob/main/Module%2002/Mini_Project_02_Finance_Tracker_Profile_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mini Project 02: Finance Tracker Profile Setup
#
# In this project, you will build the first component of our semester-long Personal Finance Tracker: the user profile setup. This project collates many of the exercises from this week’s activities. This is intentional, and by combining these exercises you can reflect on your progress and see how well you’re following the industry best practices we espouse. These practices include:
#
# - **Meaningful Notebook Naming:** Give your notebook a clear, descriptive name (e.g., `finance_tracker_profile_setup.ipynb`).
# - **Frequent Saves & Version Control:** Save your work often and use descriptive commit messages when uploading to GitHub.
# - **Descriptive Variable Names:** Use names like `user_name`, `theme_color`, etc., to clearly convey their purpose.
# - **Code Comments & Documentation:** Use text cells and inline comments to document your thought process.
# - **Critical Use of AI:** Ask follow-up questions if anything is unclear, and verify that AI suggestions align with the basics you’ve learnt (i.e., using input(), print(), basic data types, and variables).
#
# > **Tip:** Review these best practices periodically during the project to reinforce good coding habits.
#
# Let's get started!

# %% [markdown]
# ---
#
# ## Project Overview and Instructions
#
# In this project, you'll create a program that:
# 1. **Collects User Profile Information:**
#    Ask for the user's name, preferred app theme colour, primary currency, and a main savings goal.
# 2. **Displays a Personalised Welcome Message:**
#    Outputs a clear summary message using the collected data to confirm the profile setup.
#
# **Project Steps:**
# 1. **State the Problem**
# 2. **Describe Input and Output**
# 3. **Work the Problem by Hand**
# 4. **Develop an Algorithm (Pseudocode)**
# 5. **Write the Code**
# 6. **Reflect (your lab exit ticket)**
#
# > **How to use this notebook:** work through the steps in order. Each step tells you what to do, then gives you a **Your turn** cell to do it in. Read the example, complete your own version, then move on. In Step 5 you will start from example code and then take it further.
#
# ---

# %% [markdown]
# ## Step 1: State the Problem
#
# **What to do:** In your own words, write down what this program should achieve. No code yet, just get the goal clear in plain language.
#
# **Example:**
# - **Goal:** Build a program that creates a user profile for a finance tracker by collecting some initial settings and displaying a personalised welcome message.
# - **Data to gather:** the user's name, preferred theme colour, primary currency, and main savings goal.
#
# > **AI Usage Tip:**
# > If you're unsure whether your problem statement is clear, ask an AI tool:
# > "Can you restate my description of a Finance Tracker Profile Setup program using only input(), print(), and variables?"
# > Review the response to ensure it aligns with your current learning.

# %% [markdown]
# ### Your turn
#
# Double-click this cell to edit it, then replace the line below with your own words.
#
# *[ The program is to create a user profile for a finance tracker. The user could customise the tracker by gathering the data of theme colour, primary currency and main savings goal. ]*

# %% [markdown]
# ---
#
# ## Step 2: Describe Input and Output
#
# **What to do:** List every piece of information your program will ask for (the inputs), and write out the exact message you want it to print (the output). Pinning down the wording now makes the coding much easier later.
#
# **Example:**
#
# **Inputs:**
# - `user_name` (string)
# - `theme_color` (string)
# - `primary_currency` (string)
# - `main_savings_goal` (string)
#
# **Expected output:** a message like:
# > "Welcome to your Personal Finance Tracker, [user_name]! Your profile is ready. The app will use a [theme_color] theme and all amounts will be in [primary_currency]. Let's start working towards your goal of saving for a [main_savings_goal]!"
#
# > **Tip:** Mapping your inputs to the expected output helps you visualise the overall flow of your program.
#
# > **AI Usage Tip:**
# > Ask, "What are some creative ways to format this welcome message for a finance app using only the basics?" and verify that the suggestions adhere to input(), print(), and basic variables.

# %% [markdown]
# ### Your turn
#
# Double-click to edit. List your inputs, then write the target output message you are aiming for.
#
# **My inputs:**
# - *[ user_name ]*
# - *[ theme_colour ]*
# - *[ primary_currency ]*
# - *[ main_savings_goal ]*
#
# **My expected output:**
# > *[ Welcome to your Personal Finance Tracker, [user_name]! Your profile is ready. The app will use a [theme_color] theme and all amounts will be in [primary_currency]. Let's start working towards your goal of saving for a [main_savings_goal]! ]*

# %% [markdown]
# ## Step 3: Work the Problem by Hand
#
# **What to do:** Before writing any code, pretend you are the computer. Pick some sample answers and write out, by hand, exactly what the program should print for them. This becomes your test case.
#
# **Example:** if the user enters:
# - `user_name` = "Alex"
# - `theme_color` = "dark"
# - `primary_currency` = "AUD"
# - `main_savings_goal` = "holiday"
#
# then the program should print:
# > "Welcome to your Personal Finance Tracker, Alex! Your profile is ready. The app will use a dark theme and all amounts will be in AUD. Let's start working towards your goal of saving for a holiday!"
#
# > **Tip:** Try a couple of different sample answers to be sure your plan gives a clear, consistent result.

# %% [markdown]
# ### Your turn
#
# Double-click to edit. Choose your own sample answers and write the output you expect by hand.
#
# **My sample answers:** *[ name, theme colour, currency, savings goal ]*
#
# **Expected output:**
# > *[ write out the full message for your sample answers ]*

# %% [markdown]
# ---
#
# ## Step 4: Develop an Algorithm (Pseudocode)
#
# **What to do:** Turn your plan into pseudocode: the logical steps of your program written in plain language. It does not need to be valid Python. You are just describing the order of what happens.
#
# **Example:**
#
# ```plain
# 1. Start the program.
# 2. Prompt the user for their name and store it.
# 3. Prompt for their preferred theme colour and store it.
# 4. Prompt for their primary currency and store it.
# 5. Prompt for their main savings goal and store it.
# 6. Build a welcome message using the stored inputs.
# 7. Print the message.
# 8. End the program.
# ```
#
# > **AI Usage Tip:**
# > Ask an AI tool, "Can you review my pseudocode for a Finance Tracker Profile Setup program and suggest improvements?" Ensure that any suggestions stay within the basics you have learnt.

# %%
# STEP 4: Your pseudocode
# Pseudocode is your plan in plain language. It does not need to run.
# Edit the lines below: add, remove, or reword the steps to match your plan.

# 1. Start the program.
# 2. user_name
# 3. theme_colour
# 4. primary_currency
# 5. main_savings_goal
# 6.
# 7. Print the message.
# 8. End the program.

# %% [markdown]
# ---
#
# ## Step 5: Write the Code
#
# **What to do:** Now turn your pseudocode into real Python, using only what you know so far: `input()`, `print()`, variables, and basic operations. Below is one example solution. Run it, read it line by line, and check how each part lines up with your pseudocode.

# %%
# Collect user information for their financial profile
user_name = input("What is your name? ")
theme_color = input("What color would you like for your app theme? (e.g., blue, green, dark) ")
primary_currency = input("What is your primary currency? (e.g., AUD, USD, EUR) ")
main_savings_goal = input("What is one big savings goal you have? (e.g., New Car, Holiday) ")

# Construct the personalized welcome message
summary = ("Welcome to your Personal Finance Tracker, " + user_name + "! Your profile is ready. " + \
           "The app will use a " + theme_color + " theme and all amounts will be in " + \
           primary_currency + ". Let's start working towards your goal of saving for a " + \
           main_savings_goal + "!")

# Display the summary message
print(summary)

# %%
user_name = input("What is your name? ")
theme_color = input("What color would you like for your app theme? (e.g., blue, green, dark) ")
primary_currency = input("What is your primary currency? (e.g., AUD, USD, EUR) ")
main_savings_goal = input("What is one big savings goal you have? (e.g., New Car, Holiday) ")

summary = ("Welcome to your Personal Finance Tracker, " + user_name + "! Your profile is ready. " + \
           "The app will use a " + theme_color + " theme and all amounts will be in " + \
           primary_currency + ". Let's start working towards your goal of saving for a " + \
           main_savings_goal + "!")

print(summary)
# Out:
# What is your name? ken
# What color would you like for your app theme? (e.g., blue, green, dark) blue
# What is your primary currency? (e.g., AUD, USD, EUR) AUD
# What is one big savings goal you have? (e.g., New Car, Holiday) Holiday
# Welcome to your Personal Finance Tracker, ken! Your profile is ready. The app will use a blue theme and all amounts will be in AUD. Let's start working towards your goal of saving for a Holiday!

# %% [markdown]
# ### Now go further
#
# The example above is only a starting point. Your task is to extend it with at least one feature of your own. Keep within what you know so far: `input()`, `print()`, variables, and basic operations.
#
# A few ideas to spark something (pick one, combine a few, or invent your own):
# - Ask for one more preference and work it into the summary.
# - Ask the user for a number, such as a monthly saving amount, and show a small calculation, like how much that adds up to over a year.
# - Reformat the welcome message so it prints across several lines, or reads the profile back as a neat list.
#
# You can use an AI tool to help, but keep the help light: ask it to explain an idea or check your code, rather than write the whole thing for you. Then make it your own.

# %%
# Your extended version.
# Start from the example above, then add at least one new feature of your own.
# Keep to what you know: input(), print(), variables, and basic operations.
# Every month you save $. In [no of months] months time you will have [total_saving_amount] to spend on your trip. Bon voyage!
# Your code here:

# %%
monthly_saving_amount = int(input ("What is your monthly saving amount? "))
no_months = int(input ("How many months do you want to save for? "))
total_saving_amount = int(monthly_saving_amount) * int(no_months)

print(f"{summary} \nEvery month you save {monthly_saving_amount}. In {no_months} months time you will have {total_saving_amount} to spend on your trip. Bon voyage!")
# Out:
# What is your monthly saving amount? 120
# How many months do you want to save for? 6
# Welcome to your Personal Finance Tracker, ken! Your profile is ready. The app will use a blue theme and all amounts will be in AUD. Let's start working towards your goal of saving for a Holiday!
# Every month you save 120. In 6 months time you will have 720 to spend on your trip. Bon voyage!

# %% [markdown]
# ### Enhancing the Savings Tracker
#
# Let's add more details to the savings tracker to make it more comprehensive. We can ask for the target amount for the savings goal and how much has already been saved. This will allow us to calculate the remaining amount needed and an estimated time to reach the goal.

# %%
goal_amount = int(input(f"What is the target amount for your {main_savings_goal}? "))
current_saved_amount = int(input("How much have you already saved towards this goal? "))
# Out:
# What is the target amount for your Holiday? 2000
# How much have you already saved towards this goal? 1000

# %%
amount_needed = goal_amount - current_saved_amount

# Calculate estimated months to reach the goal
if monthly_saving_amount > 0:
    estimated_months_to_goal = amount_needed // monthly_saving_amount
    # Add 1 month if there's a remainder, meaning an extra month will be needed to cover it
    if amount_needed % monthly_saving_amount > 0:
        estimated_months_to_goal += 1
else:
    estimated_months_to_goal = 'N/A' # Cannot reach goal if no monthly saving

# %%
print(f"{summary}\n\nYour goal is to save ${goal_amount} for your {main_savings_goal}. \nYou have already saved ${current_saved_amount}, so you need ${amount_needed} more. \nWith your current monthly saving of ${monthly_saving_amount}, you are estimated to reach your goal in about ${estimated_months_to_goal} months. \nKeep up the great work!")
# Out:
# Welcome to your Personal Finance Tracker, ken! Your profile is ready. The app will use a blue theme and all amounts will be in AUD. Let's start working towards your goal of saving for a Holiday!
#
# Your goal is to save $2000 for your Holiday.
# You have already saved $1000, so you need $1000 more.
# With your current monthly saving of $120, you are estimated to reach your goal in about $9 months.
# Keep up the great work!

# %% [markdown]
# ## Lab Exit Ticket: Reflection
#
# This week's exit ticket is a short written reflection, submitted on Blackboard. Aim for around 250 to 300 words in total, roughly the length of an abstract. We care far more about an honest, self-aware answer than a polished one, so write what is actually true for you, not what you think sounds good.
#
# ### Part 1: Your new learning
#
# Look back at today's concepts: data types, variables, input and output, and operations. Be honest about where you are:
#
# - After the tutorial, how clear are these to you? Which ones clicked, and which are still fuzzy?
# - For anything still unclear, what is your plan to get it straight? For example, redoing an activity, asking in the next lab, or working through it with an AI tutor.
#
# After the tutorial, programming in python is quiet easy and enjoyable. Input and output are easy to understand and execute. Integers are a little bit more difficult to understand and implement naturally to the exercises. I used a lot of f-string formatting in the exercises to make it sleamless to type and cleaner to look at.
#
# ### Part 2: Your AI workflow
#
# You are building towards a solid, AI-assisted developer process. Describe, with some real detail, how you actually use AI when you code:
#
# - Which tools do you reach for, and how do you move between them? For example, "I click on a code cell and use the built-in Gemini explain or transform option, and I keep a ChatGPT tab open to go back and forth between them."
# - Roughly how many rounds of prompting does it take you to reach something that is "good enough for me" on a typical task or activity? Give your best estimate.
# - Do you think this is an efficient way to work? Why, or why not?
# - Finally, ask an AI tool to suggest one or two ways you could improve your AI-assisted coding workflow. Note what it suggested, and say whether you agree.
#
# The in built AI assistant is quiet helpful in looking through my mistakes. There were a small number of rounds of prompting to reach what I desired because the AI would auto-generate which was a little frustrating.
#
# > **Remember:** honest over polished. There is no right answer here. A rough but truthful reflection is exactly what we are looking for.
